# %% [markdown]
# Automatic finetuning implementation test

# %%
PATH_PREFIX = '../../'
import sys
sys.path.append(PATH_PREFIX)

# %%
import torch
import torch.nn as nn
import os

from data.mnist import MnistDataset
from models.lenet.lenet import LeNet5
from data.utils.mnist_utils import *
from utils.quantize import *
from utils.weight_sharing import *
from utils.plot import *

# %%
LEARNING_RATE = 0.0001
BATCH_SIZE = 32
N_CLASSES = 10
DEVICE = 'cpu'
EPOCHS = 100
NET_TYPE = 'tanh'
PREC_REDUCT = 'f2'

NET_PATH = os.path.join(PATH_PREFIX, f'models/lenet/saves/lenet_{NET_TYPE}.save')
SAVE_DATA = os.path.join(PATH_PREFIX, 'results/test_share.csv')

FOCUS_SEARCH_SPACE = np.arange(0, 10, 0.2)
FIXED_SPREAD = [2, 2, 2, 2, 2]
LAYER = [0, 1, 2, 3, 4]
SHARE_CLUSTERS = [3, 5, 3, 2, 2]
# tested tanh shares: [6, 17, 31, 4, 2], [3, 29, 2, 34, 4]

# %%
dataset = MnistDataset(BATCH_SIZE, os.path.join(PATH_PREFIX, 'data'), val_split=0.5)
model = LeNet5(N_CLASSES, NET_TYPE)
criterion = nn.CrossEntropyLoss()

lam_opt = lambda mod : torch.optim.Adam(mod.parameters(), lr=LEARNING_RATE)
lam_train = lambda opt, epochs : train_net(model, criterion, opt, dataset, epochs, device=DEVICE)
lam_test = lambda : get_accuracy(model, dataset.test_dl, DEVICE)

lam_test2 = lambda : get_accuracy(model, dataset.train_dl, DEVICE)
lam_test3 = lambda : get_accuracy(model, dataset.valid_dl, DEVICE)

ws_controller = WeightShare(model, lam_test, lam_opt, lam_train)
ws_controller.print_layers_info()
# Out:
# layer_name #weights #bias w_locked CR
# feature_extractor.0 150 6 False 1.00
# feature_extractor.3 2400 16 False 1.00
# feature_extractor.6 48000 120 False 1.00
# classifier.0 10080 84 False 1.00
# classifier.2 840 10 False 1.00
# Sum num weights, bias:  61470 236
# Compression rate 1.00

# %%
optimizer = lam_opt(model)
train_settings = [criterion, optimizer, dataset, EPOCHS, DEVICE, 1, True]

get_trained(model, NET_PATH, train_settings)

# %%
before_acc = ws_controller.test()
before_acc
# Out:
# 0.9864

# %%
ws_controller.finetuned_mod(SHARE_CLUSTERS, FOCUS_SEARCH_SPACE, FIXED_SPREAD, LAYER, plot=True, prec_reduct=[PREC_REDUCT for _ in ws_controller.model_layers], 
    savefile=os.path.join(PATH_PREFIX, f'results/finetuning/lenet_{NET_TYPE}_{SHARE_CLUSTERS}_{PREC_REDUCT}.csv'))
# Out:
# [2.0, 2.8000000000000003, 4.800000000000001, 6.4, 0.0]

# %% [markdown]
# Finetuned  performance

# %%
acc = ws_controller.test()

# finetuned relu lenet - 0.9782
# finetuned tanh lenet - 0.9868, 0.9808, 0.9838
acc
# Out:
# 0.9802

# %%
(before_acc - acc) * 100
# Out:
# 0.6200000000000094

# %%
# train dataset test
lam_test2()
# Out:
# 0.9843666666666666

# %%
# validation dataset test
lam_test3()
# Out:
# 0.9828

# %% [markdown]
# Not finetuned performance

# %%
ws_controller.reset()

ws_controller.share(SHARE_CLUSTERS)

# not finetuned relu lenet - 0.9776
# not finetuned tanh lenet - 0.9854, 0.9794, 0.9824
# Out:
# {'accuracy': 0.9768,
#  'compression': 19.95951783868877,
#  'inertias': [1.1039032936096191,
#   3.3266289234161377,
#   30.157751083374023,
#   37.053688049316406,
#   13.429511070251465],
#  'times': {'train': 0,
#   'share': 1.4777536392211914,
#   'test': 1.4165959358215332}}

# %%
# train dataset test
lam_test2()
# Out:
# 0.9836833333333334

# %%
# validation dataset test
lam_test3()
# Out:
# 0.982
